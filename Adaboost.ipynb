# %%
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.ensemble import AdaBoostRegressor

# Instantiate the AdaBoost model
regressor = AdaBoostRegressor(
    sestimator=base_estimator,
    n_estimators=100,      # Number of boosting stages
    learning_rate=0.1,     # Controls the contribution of each weak learner
    random_state=0         # Use the same random state for consistency
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 from sklearn.ensemble import AdaBoostRegressor
#       3 # Instantiate the AdaBoost model
#       4 regressor = AdaBoostRegressor(
# ----> 5     sestimator=base_estimator,
#       6     n_estimators=100,      # Number of boosting stages
#       7     learning_rate=0.1,     # Controls the contribution of each weak learner
#       8     random_state=0         # Use the same random state for consistency
#       9 )
#
# NameError: name 'base_estimator' is not defined

# %%
RandomForestRegressor(n_estimators=50,random_state=0)
# Out:
# RandomForestRegressor(n_estimators=50, random_state=0)

# %%
y_pred=regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.8498329315421834

# %%
import pickle
filename="finalized_model_adaboost.sav"
pickle.dump(regressor,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("finalized_model_adaboost.sav",'rb'))
result=loaded_model.predict([[70,40,3,1,2]])
# Out:
# /Users/harikrishnan/Documents/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# ,  warnings.warn(

# %%
result
# Out:
# array([48564.4864864])
