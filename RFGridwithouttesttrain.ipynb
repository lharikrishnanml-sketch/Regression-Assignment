# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age','bmi','children','sex_male','smoker_yes']]
dep=dataset[['charges']]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
#from sklearn.model_selection import GridSearchCV
#from sklearn.tree import DecisionTreeRegressor
#param_grid={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2'],'n_estimators':[10,100]}
#grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
#grid.fit(indep,dep)

from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# Updated parameter names for newer scikit-learn versions
param_grid = {
    'criterion': ['squared_error', 'absolute_error', 'friedman_mse'],
    'max_features': ['sqrt', 'log2'],
    'n_estimators': [10, 50, 100, 150]
}

grid = GridSearchCV(
    RandomForestRegressor(random_state=0),
    param_grid,
    refit=True,
    verbose=3,
    n_jobs=-1,
    cv=5  # 5-fold cross-validation
)

grid.fit(indep, dep.values.ravel())
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=0), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 50, 100, 150]},
#              verbose=3)

# %%
GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
param_grid={'criterion': ['mse', 'mae'],
'max_features': ['auto', 'sqrt', 'log2'],
'n_estimators': [10, 100]},
verbose=3)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
#grid_predictions=grid.predict(X_test)

# %%
#from sklearn.metrics import r2_score
#r_score=r2_score(y_test,grid_predictions)
print("The R_ score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_ score value for best parameter {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.038704      0.002731         0.005970        0.000176
# 1        0.233682      0.004557         0.013538        0.000841
# 2        0.472166      0.002865         0.022366        0.000607
# 3        0.705751      0.003870         0.031756        0.000464
# 4        0.052106      0.001156         0.005578        0.000405
# 5        0.236998      0.000650         0.012540        0.000260
# 6        0.470155      0.010022         0.022493        0.001282
# 7        0.720019      0.021702         0.032353        0.000902
# 8        0.174452      0.002939         0.005486        0.000160
# 9        0.879942      0.012081         0.013108        0.000936
# 10       1.746394      0.012465         0.021384        0.000541
# 11       2.585696      0.057282         0.029473        0.000960
# 12       0.180969      0.004590         0.005283        0.000187
# 13       0.872243      0.011040         0.011944        0.000243
# 14       1.718291      0.007774         0.021707        0.001210
# 15       2.276609      0.277316         0.023417        0.004344
# 16       0.051784      0.001410         0.005360        0.000100
# 17       0.231860      0.003201         0.012700        0.000624
# 18       0.461494      0.005674         0.020979        0.000664
# 19       0.682914      0.004127         0.029586        0.000477
# 20       0.050255      0.000424         0.005431        0.000396
# 21       0.232352      0.002469         0.012398        0.000366
# 22       0.448668      0.005157         0.017266        0.001935
# 23       0.538625      0.019941         0.020451        0.000188
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               sqrt                  10
# 1    squared_error               sqrt                  50
# 2    squared_error               sqrt                 100
# 3    squared_error               sqrt                 150
# 4    squared_error               log2                  10
# 5    squared_error               log2                  50
# 6    squared_error               log2                 100
# 7    squared_error               log2                 150
# 8   absolute_error               sqrt                  10
# 9   absolute_error               sqrt                  50
# 10  absolute_error               sqrt                 100
# 11  absolute_error               sqrt                 150
# 12  absolute_error               log2                  10
# 13  absolute_error               log2                  50
# 14  absolute_error               log2                 100
# 15  absolute_error               log2                 150
# 16    friedman_mse               sqrt                  10
# 17    friedman_mse               sqrt                  50
# 18    friedman_mse               sqrt                 100
# 19    friedman_mse               sqrt                 150
# 20    friedman_mse               log2                  10
# 21    friedman_mse               log2                  50
# 22    friedman_mse               log2                 100
# 23    friedman_mse               log2                 150
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.841175
# 1   {'criterion': 'squared_error', 'max_features':...           0.855768
# 2   {'criterion': 'squared_error', 'max_features':...           0.858913
# 3   {'criterion': 'squared_error', 'max_features':...           0.860065
# 4   {'criterion': 'squared_error', 'max_features':...           0.841175
# 5   {'criterion': 'squared_error', 'max_features':...           0.855768
# 6   {'criterion': 'squared_error', 'max_features':...           0.858913
# 7   {'criterion': 'squared_error', 'max_features':...           0.860065
# 8   {'criterion': 'absolute_error', 'max_features'...           0.847002
# 9   {'criterion': 'absolute_error', 'max_features'...           0.854763
# 10  {'criterion': 'absolute_error', 'max_features'...           0.858995
# 11  {'criterion': 'absolute_error', 'max_features'...           0.860316
# 12  {'criterion': 'absolute_error', 'max_features'...           0.847002
# 13  {'criterion': 'absolute_error', 'max_features'...           0.854763
# 14  {'criterion': 'absolute_error', 'max_features'...           0.858995
# 15  {'criterion': 'absolute_error', 'max_features'...           0.860316
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.839427
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.854600
# 18  {'criterion': 'friedman_mse', 'max_features': ...           0.857799
# 19  {'criterion': 'friedman_mse', 'max_features': ...           0.859341
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.839427
# 21  {'criterion': 'friedman_mse', 'max_features': ...           0.854600
# 22  {'criterion': 'friedman_mse', 'max_features': ...           0.857799
# 23  {'criterion': 'friedman_mse', 'max_features': ...           0.859341
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.760981           0.841534           0.818059
# 1            0.773370           0.855098           0.828924
# 2            0.775693           0.858206           0.826274
# 3            0.777346           0.859156           0.828209
# 4            0.760981           0.841534           0.818059
# 5            0.773370           0.855098           0.828924
# 6            0.775693           0.858206           0.826274
# 7            0.777346           0.859156           0.828209
# 8            0.766992           0.851781           0.815199
# 9            0.780472           0.860135           0.828803
# 10           0.784290           0.860922           0.827635
# 11           0.782035           0.857814           0.827312
# 12           0.766992           0.851781           0.815199
# 13           0.780472           0.860135           0.828803
# 14           0.784290           0.860922           0.827635
# 15           0.782035           0.857814           0.827312
# 16           0.762746           0.851671           0.818152
# 17           0.774763           0.855715           0.828399
# 18           0.777109           0.858892           0.825924
# 19           0.778156           0.859862           0.827780
# 20           0.762746           0.851671           0.818152
# 21           0.774763           0.855715           0.828399
# 22           0.777109           0.858892           0.825924
# 23           0.778156           0.859862           0.827780
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.830206         0.818391        0.029967               23
# 1            0.839353         0.830503        0.030293               17
# 2            0.840158         0.831849        0.030597               13
# 3            0.840603         0.833076        0.030314                5
# 4            0.830206         0.818391        0.029967               23
# 5            0.839353         0.830503        0.030293               17
# 6            0.840158         0.831849        0.030597               13
# 7            0.840603         0.833076        0.030314                5
# 8            0.830773         0.822349        0.030530               19
# 9            0.839414         0.832718        0.028381                9
# 10           0.843662         0.835101        0.028101                1
# 11           0.846018         0.834699        0.028798                3
# 12           0.830773         0.822349        0.030530               19
# 13           0.839414         0.832718        0.028381                9
# 14           0.843662         0.835101        0.028101                1
# 15           0.846018         0.834699        0.028798                3
# 16           0.830288         0.820457        0.030876               21
# 17           0.839275         0.830550        0.029680               15
# 18           0.839721         0.831889        0.029994               11
# 19           0.840138         0.833055        0.030005                7
# 20           0.830288         0.820457        0.030876               21
# 21           0.839275         0.830550        0.029680               15
# 22           0.839721         0.831889        0.029994               11
# 23           0.840138         0.833055        0.030005                7

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("children:"))
sex_male_input=int(input("SEX M 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 34
# BMI: 23
# children: 1
# SEX M 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
# Out:
# /Users/harikrishnan/Documents/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
print("Future_Predictions={}".format(Future_Prediction))
# Out:
# Future_Predictions=[7797.48863645]
