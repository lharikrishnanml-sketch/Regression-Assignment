# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age','bmi','children','sex_male','smoker_yes']]
dep=dataset[['charges']]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'criterion': ['squared_error', 'friedman_mse', 'absolute_error'],
    'splitter': ['best', 'random'],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 10, 20],
    'min_samples_leaf': [1, 5, 10],
    'max_features': ['sqrt', 'log2']
}
grid = GridSearchCV(
    DecisionTreeRegressor(random_state=0),
    param_grid,
    refit=True,
    verbose=3,
    n_jobs=-1,
    cv=5
)

grid.fit(indep, dep.values.ravel())
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.690 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.734 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.650 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.839 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.741 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.839 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.741 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.740 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best;, score=0.879 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=random;, score=0.750 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=best;, score=0.778 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.825 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.659 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.717 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.695 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.748 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.817 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.834 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.771 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, splitter=best;, score=0.879 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, splitter=best;, score=0.778 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, splitter=best;, score=0.815 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=2, splitter=random;, score=0.746 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.815 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.800 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.742 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.817 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=random;, score=0.716 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=random;, score=0.750 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=best;, score=0.823 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=best;, score=0.707 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.742 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.817 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.723 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.766 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.820 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.773 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.836 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.813 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.775 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.716 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.801 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.752 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best;, score=0.825 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best;, score=0.659 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best;, score=0.879 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best;, score=0.778 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.690 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.674 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.540 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.696 total time=   0.0s[CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.666 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.789 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.810 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.710 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.803 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.721 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.803 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.721 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.798 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best;, score=0.659 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=random;, score=0.716 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random;, score=0.746 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.676 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.731 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.813 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.674 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.650 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.843 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, splitter=best;, score=0.815 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, splitter=random;, score=0.746 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, splitter=random;, score=0.676 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, splitter=random;, score=0.731 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.823 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.707 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.881 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.778 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.836 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.813 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.791 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.686 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.678 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.836 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.732 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.765 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.716 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.750 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.666 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.635 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.717 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.699 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.688 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.656 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=30, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.853 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=30, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.803 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=30, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.839 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=30, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.770 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=30, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.709 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=30, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.724 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=30, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.721 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=30, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.741 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=30, max_features=log2, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.805 total time=   0.0s[CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.717 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.817 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.827 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.793 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.834 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.770 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.834 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.770 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.805 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.775 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=random;, score=0.731 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=best;, score=0.815 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.879 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.778 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.646 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.694 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.842 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.797 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.709 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.724 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.740 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.826 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.775 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.716 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.769 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.775 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.804 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.819 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.678 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.836 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.732 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.765 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.666 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.635 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.717 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.699 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.688 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.656 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.540 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.658 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.740 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.826 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.775 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.716 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.801 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.752 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=10, min_samples_split=2, splitter=best;, score=0.825 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=10, min_samples_split=2, splitter=best;, score=0.659 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=30, max_features=log2, min_samples_leaf=10, min_samples_split=10, splitter=best;, score=0.815 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=30, max_features=log2, min_samples_leaf=10, min_samples_split=10, splitter=random;, score=0.746 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=30, max_features=log2, min_samples_leaf=10, min_samples_split=10, splitter=random;, score=0.676 total time=   0.0s[CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.674 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best;, score=0.825 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.690 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.674 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.786 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.759 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.839 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.770 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.775 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.745 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.814 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.737 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.820 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.773 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.836 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.813 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.763 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.757 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.764 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.821 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.714 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.816 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.775 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.745 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.834 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.771 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.853 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.803 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.839 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.770 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.709 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.724 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.721 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.741 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.834 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.771 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.853 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.803 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.839 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.770 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.815 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.746 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.676 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.731 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.716 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.750 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.666 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.596 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.717 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.695 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.540 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.801 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=best;, score=0.825 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random;, score=0.731 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.815 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.746 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.721 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.741 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.676 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.731 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.716 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.750 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.868 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.791 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.841 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.739 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.810 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.793 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.650 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.843 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.763 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.710 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.834 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.771 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.825 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.659 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.879 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.778 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.815 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.746 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.676 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.731 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.848 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.798 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.740 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.826 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.775 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.716 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.801 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.752 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best;, score=0.825 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best;, score=0.659 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best;, score=0.879 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best;, score=0.778 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=best;, score=0.815 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=random;, score=0.746 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=random;, score=0.676 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=random;, score=0.731 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.721 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.741 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.834 total time=   0.0s[CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.646 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, splitter=random;, score=0.676 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=best;, score=0.659 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, splitter=random;, score=0.716 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.716 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.750 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.827 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.734 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.879 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.778 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.815 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.746 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.732 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.765 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.834 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.761 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.748 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.817 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.740 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.789 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.827 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.734 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.842 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.797 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.709 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.724 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.721 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.741 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.805 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.761 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.848 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.798 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.721 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.741 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.805 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.761 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.848 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.798 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.740 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.826 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.775 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.716 total time=   0.0s
# ...
# [CV 5/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.786 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.759 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.748 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.817 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.740 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.789 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.540 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.696 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.646 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.693 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.813 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.674 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.814 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.780 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.786 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.759 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.748 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.817 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.740 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.789 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.827 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.734 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.810 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.793 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.650 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.843 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.763 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.710 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.834 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.771 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.853 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.803 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.839 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.770 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.709 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.724 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.721 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.741 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.834 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.771 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.853 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.803 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.839 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.770 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.709 total time=   0.0s[CV 2/5] END criterion=squared_error, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.674 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.810 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.793 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.853 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.803 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.839 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.770 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.709 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.724 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.721 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.741 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.540 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.658 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.646 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.694 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.813 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.674 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.814 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.780 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.748 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.817 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.740 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.789 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.827 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.734 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.842 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.797 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=best;, score=0.810 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.793 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.650 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.843 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.763 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, splitter=random;, score=0.710 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.834 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.771 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.791 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.686 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.678 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.836 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.732 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.765 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.820 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.773 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.836 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.813 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.791 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.686 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.678 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.836 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.732 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.765 total time=   0.0s
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=0), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_depth': [None, 10, 20, 30],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 5, 10],
#                          'min_samples_split': [2, 10, 20],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
grid
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=0), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_depth': [None, 10, 20, 30],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 5, 10],
#                          'min_samples_split': [2, 10, 20],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
#grid_predictions=grid.predict(X_test)

# %%
#from sklearn.metrics import r2_score
#r_score=r2_score(y_test,grid_predictions)
print("The R_ score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_ score value for best parameter {'criterion': 'squared_error', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.010352      0.000933         0.003970        0.000177
# 1         0.009572      0.001034         0.004077        0.000226
# 2         0.007923      0.000097         0.003717        0.000178
# 3         0.006420      0.000474         0.003837        0.000137
# 4         0.006385      0.000252         0.003638        0.000496
# ..             ...           ...              ...             ...
# 427       0.021171      0.000756         0.003204        0.000154
# 428       0.023315      0.002135         0.003128        0.000194
# 429       0.024049      0.001547         0.002920        0.000025
# 430       0.026315      0.002568         0.003029        0.000133
# 431       0.020874      0.001348         0.002789        0.000253
#
#     param_criterion param_max_depth param_max_features  \
# 0     squared_error            None               sqrt
# 1     squared_error            None               sqrt
# 2     squared_error            None               sqrt
# 3     squared_error            None               sqrt
# 4     squared_error            None               sqrt
# ..              ...             ...                ...
# 427  absolute_error              30               log2
# 428  absolute_error              30               log2
# 429  absolute_error              30               log2
# 430  absolute_error              30               log2
# 431  absolute_error              30               log2
#
#      param_min_samples_leaf  param_min_samples_split param_splitter  \
# 0                         1                        2           best
# 1                         1                        2         random
# 2                         1                       10           best
# 3                         1                       10         random
# 4                         1                       20           best
# ..                      ...                      ...            ...
# 427                      10                        2         random
# 428                      10                       10           best
# 429                      10                       10         random
# 430                      10                       20           best
# 431                      10                       20         random
#
#                                                 params  split0_test_score  \
# 0    {'criterion': 'squared_error', 'max_depth': No...           0.665762
# 1    {'criterion': 'squared_error', 'max_depth': No...           0.674085
# 2    {'criterion': 'squared_error', 'max_depth': No...           0.812858
# 3    {'criterion': 'squared_error', 'max_depth': No...           0.758676
# 4    {'criterion': 'squared_error', 'max_depth': No...           0.826531
# ..                                                 ...                ...
# 427  {'criterion': 'absolute_error', 'max_depth': 3...           0.691026
# 428  {'criterion': 'absolute_error', 'max_depth': 3...           0.863164
# 429  {'criterion': 'absolute_error', 'max_depth': 3...           0.691026
# 430  {'criterion': 'absolute_error', 'max_depth': 3...           0.863164
# 431  {'criterion': 'absolute_error', 'max_depth': 3...           0.691026
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0             0.596286           0.717470           0.694542
# 1             0.540022           0.695699           0.646326
# 2             0.674422           0.814185           0.780056
# 3             0.747560           0.817213           0.740104
# 4             0.733928           0.842187           0.796501
# ..                 ...                ...                ...
# 427           0.655700           0.765314           0.664957
# 428           0.758817           0.688796           0.789964
# 429           0.655700           0.765314           0.664957
# 430           0.758817           0.688796           0.789964
# 431           0.655700           0.765314           0.664957
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.690452         0.672902        0.041674              417
# 1             0.694315         0.650089        0.057864              421
# 2             0.785542         0.773412        0.051398              193
# 3             0.788517         0.770414        0.028624              211
# 4             0.809889         0.801807        0.037263               61
# ..                 ...              ...             ...              ...
# 427           0.746852         0.704770        0.043859              363
# 428           0.846905         0.789529        0.062936              133
# 429           0.746852         0.704770        0.043859              363
# 430           0.846905         0.789529        0.062936              133
# 431           0.746852         0.704770        0.043859              363
#
# [432 rows x 19 columns]

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("children:"))
sex_male_input=int(input("SEX M 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 76
# BMI: 23
# children: 1
# SEX M 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
# Out:
# /Users/harikrishnan/Documents/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
print("Future_Predictions={}".format(Future_Prediction))
# Out:
# Future_Predictions=[14885.90742222]
